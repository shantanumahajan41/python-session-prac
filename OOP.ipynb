# %% [markdown]
# # Object Oriented Programming
# 1. Encapsulation
# 2. Abstraction
# 3. Inheritance
# 4. Polymorphism
# 5.

# %%
#A minimal example of a class

# %%
a = 1

# %%
print(isinstance(a, object))
# Out:
# True

# %%
a = 'dog'

# %%
print(isinstance(a, object))
# Out:
# True

# %%
a = print

# %%
print(isinstance(a, object))
# Out:
# True

# %%
class A:
    pass

# %%
a = A

# %%
print(isinstance(a, object))
# Out:
# True

# %%
a = A()

# %%
print(isinstance(a, object))
# Out:
# True

# %%
class Person:
    pass
p = Person()
print(p)
# Out:
# <__main__.Person object at 0x00000160E8A80440>

# %%
id(p)
# Out:
# 1515731813440

# %%
hex(id(p))   #hexadecimal value...same!"
# Out:
# '0x160e8a80440'
