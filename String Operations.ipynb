# %%
a = 1
b = 2
c = 3

# %%
print(str(a) + "-" + str(b) + "-" + str(c))
# Out:
# 1-2-3

# %%
print("%d-%d-%d" % (a, b, c))
# Out:
# 1-2-3

# %%
a = "jatin"
b = 2
c = 3

# %%
print("%d-%d-%d" % (a, b, c))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print("%d-%d-%d" % (a, b, c))
#
# TypeError: %d format: a real number is required, not str

# %%
print("{}-{}-{}".format(a, b, c))
# Out:
# jatin-2-3

# %%
print("{1}-{0}-{2}".format(a, b, c))
# Out:
# 2-jatin-3

# %%
print("{lastname}, {firstname}".format(firstname = "jatin", lastname = "katyal"))
# Out:
# katyal, jatin

# %%
firstname = "jatin"
lastname = "katyal"

# %%
print(f"{lastname}, {firstname}")
# Out:
# katyal, jatin

# %%
a = "         jatin.        "

# %%
print(a.strip())
# Out:
# jatin.

# %%
a = input()
# Out:
#    yes

# %%
a == "yes"
# Out:
# False

# %%
a
# Out:
# '  yes   '

# %%
a.strip() == "yes"
# Out:
# True

# %%
a = input()
# Out:
#  1 2 3 4 5 6 7

# %%
a
# Out:
# '1 2 3 4 5 6 7'

# %%
a.split(' ')
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
a = input()
# Out:
#  1-2-3-4-5-6-7

# %%
a
# Out:
# '1-2-3-4-5-6-7'

# %%
a.split(' ')
# Out:
# ['1-2-3-4-5-6-7']

# %%
a.split('-')
# Out:
# ['1', '2', '3', '4', '5', '6', '7']

# %%
a = "jatin"

# %%
a[0] = '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a[0] = '1'
#
# TypeError: 'str' object does not support item assignment

# %%
a.replace('j', 'l')
# Out:
# 'latin'

# %%
a = 'aaabbbccc'

# %%
a.replace('a', 'z')
# Out:
# 'zzzbbbccc'

# %%
a.count('a')
# Out:
# 3

# %%
a.count('aa')
# Out:
# 1
