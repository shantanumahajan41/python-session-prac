# %%
print("Hello World")
# Out:
# Hello World

# %%
#this is a comment

# %%
'''
this is multiline comment
but it is strings actually
'''
# Out:
# '\nthis is multiline comment\nbut it is strings actually\n'

# %%
a = 3

# %%
print(a)
type(a)
# Out:
# 3
# int

# %%
a = 9.9

# %%
print(a)
type(a)
# Out:
# 9.9
# float

# %%
a = 2 + 6j

# %%
print(a)
type(a)
# Out:
# (2+6j)
# complex

# %%
a = 'Batman Solos'

# %%
print(a)
type(a)
# Out:
# Batman Solos
# str

# %%
a = "python"
print(a)
a = 'coding'
print(a)
a = '''
this is also a 
multi line string
'''
print (a)
a = """
And 
this 
is 
also 
multi 
line 
string
"""
print (a)
# Out:
# python
# coding
#
# this is also a
# multi line string
#
#
# And
# this
# is
# also
# multi
# line
# string
