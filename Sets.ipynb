# %% [markdown]
# # Sets
# Sets are unordered collections of simple objects. These are used when the existence of an object in a collection is more important than the order or how many times it occurs.
# Using sets, you can test for membership, whether it is a subset of another set, find the intersection between two sets, and so on.

# %%
a = { 1, 2, 3, 4 }

# %%
type(a)
# Out:
# set

# %%
a = {}

# %%
type(a)
# Out:
# dict

# %%
# therefore to create an empty set :-
a = set()

# %%
a
# Out:
# set()

# %%
a = { 1, 2, 3, 4 }

# %%
b = { 3, 4, 5, 6, 7}

# %%
a.intersection(b) #returns the common elements of both the sets
# Out:
# {3, 4}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
a - b
# Out:
# {1, 2}

# %%
for i in a:
    print(i)  #sets are not indeexable but are iterable
# Out:
# 1
# 2
# 3
# 4

# %%
a = { 1, 2, 3, 2, 3, 4, 5, 1, 2, 3, 5, 7, 4, 0, 2}

# %%
a   #all the duplicate values will be removed and only non duplicate values/unique value will be kept
# Out:
# {0, 1, 2, 3, 4, 5, 7}

# %%
len(a)
# Out:
# 7

# %%
#A common beginner level inteview questin: how to de-duplicate a list?
a = [1, 2, 1, 2, 1, 1, 2, 2]

# %%
 #simple way
list(set(a))     #but order is not ensured!
# Out:
# [1, 2]
